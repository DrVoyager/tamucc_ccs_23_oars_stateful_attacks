# %%
import random
import openpyxl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from google.colab import drive
import time
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
import os
from google.colab import files
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import balanced_accuracy_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Boundary** **Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = '/content/drive/My Drive/Boundary_Cifar10.xlsx'

# %%
# Load all sheets into a dictionary of DataFrames
df = pd.read_excel(file_path)

# %%
df['Label'] = df['Label'].replace('Malware', 'Boundary')

# %%
df.head()
# Out:
#    Iteration  Trail  Top 1 Probability  Top 2 Probability  Top 1 Label  \
# 0        1.0      1           0.965761           0.034079            6
# 1        NaN      2           0.965761           0.034079            6
# 2        NaN      3           0.965761           0.034079            6
# 3        NaN      4           0.965761           0.034079            6
# 4        NaN      5           0.965761           0.034079            6
#
#    Top 2 Label  Cache Hits  Margin Loss     Noise    offset     Label
# 0            2       False     0.931682  0.429488  0.000000  Boundary
# 1            2       False     0.931682  0.427322  0.002166  Boundary
# 2            2       False     0.931682  0.424075  0.003247  Boundary
# 3            2       False     0.931682  0.419206  0.004868  Boundary
# 4            2       False     0.931682  0.411907  0.007299  Boundary

# %%
df.tail()
# Out:
#         Iteration  Trail  Top 1 Probability  Top 2 Probability  Top 1 Label  \
# 787246       58.0      1           0.537932           0.461584            2
# 787247        NaN      2           0.537932           0.461584            2
# 787248        NaN      3           0.537932           0.461584            2
# 787249        NaN      4           0.537932           0.461584            2
# 787250        NaN      5           0.537932           0.461584            2
#
#         Top 2 Label  Cache Hits  Margin Loss     Noise    offset     Label
# 787246            6       False     0.076348  0.276431  0.039142  Boundary
# 787247            6       False     0.076348  0.275037  0.001394  Boundary
# 787248            6       False     0.076348  0.272947  0.002090  Boundary
# 787249            6       False     0.076348  0.269813  0.003133  Boundary
# 787250            6       False     0.076348  0.265115  0.004698  Boundary

# %%
df.shape
# Out:
# (787251, 11)

# %%
df = df[df['Label'] != 'Benign']

# %%
df.shape
# Out:
# (787251, 11)

# %% [markdown]
# **Benign dataset**

# %%
# Load all sheets into a dictionary of DataFrames
dff = pd.read_excel('/content/drive/My Drive/Boundary_Cifar10_Original.xlsx')

# %%
dff.shape
# Out:
# (9974, 7)

# %%
dff.tail()
# Out:
#       Top 1 Probability  Top 2 Probability  Top 1 Label  Top 2 Label  \
# 9969           0.914087       4.756780e-02            5            7
# 9970           0.999999       6.960000e-07            5            3
# 9971           1.000000       8.320000e-09            5            3
# 9972           0.856713       1.432366e-01            5            4
# 9973           0.999980       1.620000e-05            6            3
#
#       Margin Loss    offset   Label
# 9969     0.866519  0.479368  Benign
# 9970     0.999998  0.336726  Benign
# 9971     1.000000  0.150577  Benign
# 9972     0.713477  0.234203  Benign
# 9973     0.999964  0.302657  Benign

# %% [markdown]
# **NES** **Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = '/content/drive/My Drive/NES_Cifar10.csv'

# %%
df1 = pd.read_csv(file_path)

# %%
# Renaming columns
df1.rename(columns={'SortedList_First_Element': 'Top 1 Probability', 'SortedList_Second_Element': 'Top 2 Probability', 'PredictedLabel_first':'Top 1 Label', 'Predicted_Label_second':'Top 2 Label'}, inplace=True)

# %%
df1['Label'] = 'NES'

# %%
df1.head()
# Out:
#   CurrentIndex                 IndexLabel  NES_Logits_True/False  \
# 0            0                                             False
# 1            1  Estimate_Initial_Variance                  False
# 2                                                          False
# 3                                                          False
# 4                                                          False
#
#    Top 1 Probability  Top 2 Probability  Top 1 Label  Top 2 Label  \
# 0           0.999974           0.000026            7            4
# 1           0.850932           0.149067            6            2
# 2           0.877930           0.113648            6            2
# 3           0.723967           0.275976            6            2
# 4           0.785016           0.214981            2            6
#
#    Margin Loss Label
# 0     0.999949   NES
# 1     0.701865   NES
# 2     0.764282   NES
# 3     0.447991   NES
# 4     0.570035   NES

# %%
df1.shape
# Out:
# (469841, 9)

# %% [markdown]
# **Square** **Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = '/content/drive/My Drive/Square_Cifar10.csv'

# %%
df2 = pd.read_csv(file_path)

# %%
# Renaming columns
df2.rename(columns={'SortedList_First_Element': 'Top 1 Probability', 'SortedList_Second_Element': 'Top 2 Probability', 'PredictedLabel_first':'Top 1 Label', 'Predicted_Label_second':'Top 2 Label'}, inplace=True)

# %%
df2['Label'] = 'Square'

# %%
df2.head()
# Out:
#   CurrentIndex           IndexLabel  Logits_True/False  Top 1 Probability  \
# 0            0                                   False           0.550991
# 1            1  Initial_Num_Squares              False           0.997986
# 2                                                False           0.999999
# 3                                                False           0.830272
# 4                                                False           0.959118
#
#    Top 2 Probability  Top 1 Label  Top 2 Label  Margin Loss   Label
# 0       3.981260e-01            4            3     0.152865  Square
# 1       1.334710e-03            4            2     0.996651  Square
# 2       7.967977e-07            4            3     0.999998  Square
# 3       1.022182e-01            4            3     0.728054  Square
# 4       4.037444e-02            4            3     0.918744  Square

# %%
df2.shape
# Out:
# (155922, 9)

# %% [markdown]
# **HSJA Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = 'HSJA_CIFAR10.csv'

# %%
df3 = pd.read_csv(file_path)
# Out:
# <ipython-input-27-1f5a9e5b9457>:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(file_path)

# %%
# Renaming columns
df3.rename(columns={'SortedList_First_Element': 'Top 1 Probability', 'SortedList_Second_Element': 'Top 2 Probability', 'PredictedLabel_first':'Top 1 Label', 'Predicted_Label_second':'Top 2 Label'}, inplace=True)

# %%
df3['Label'] = 'QEBA / HSJA'

# %%
df3.head()
# Out:
#   CurrentIndex HSJA_Logits_True/False  Top 1 Probability  Top 2 Probability  \
# 0            0                  False           0.376380           0.253102
# 1          NaN                  False           0.744554           0.160647
# 2          NaN                  False           0.970433           0.023774
# 3          NaN                  False           0.751087           0.220022
# 4          NaN                  False           0.648171           0.303700
#
#   Attack_Status  Margin Loss        Label
# 0           NaN     0.123278  QEBA / HSJA
# 1           NaN     0.583907  QEBA / HSJA
# 2           NaN     0.946659  QEBA / HSJA
# 3           NaN     0.531065  QEBA / HSJA
# 4           NaN     0.344471  QEBA / HSJA

# %%
df3.tail()
# Out:
#         CurrentIndex HSJA_Logits_True/False  Top 1 Probability  \
# 6701986          NaN                  False           0.408709
# 6701987          NaN                  False           0.408591
# 6701988          NaN                  False           0.408583
# 6701989          NaN                  False           0.408530
# 6701990          NaN                  False           0.408550
#
#          Top 2 Probability Attack_Status  Margin Loss        Label
# 6701986           0.408350           NaN     0.000360  QEBA / HSJA
# 6701987           0.408449           NaN     0.000142  QEBA / HSJA
# 6701988           0.408468           NaN     0.000115  QEBA / HSJA
# 6701989           0.408515           NaN     0.000014  QEBA / HSJA
# 6701990           0.408497           NaN     0.000052  QEBA / HSJA

# %% [markdown]
# **QEBA Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = 'QEBA_cifar10.xlsx'

# %%
df4 = pd.read_excel(file_path)

# %%
df4.shape
# Out:
# (1048575, 6)

# %%
# Renaming columns
df4.rename(columns={'SortedList_First_Element': 'Top 1 Probability', 'SortedList_Second_Element': 'Top 2 Probability', 'PredictedLabel_first':'Top 1 Label', 'Predicted_Label_second':'Top 2 Label'}, inplace=True)

# %%
df4['Label'] = 'QEBA / HSJA'

# %%
df4.head()
# Out:
#    CurrentIndex  QEBA_Logits_True/False  Top 1 Probability  Top 2 Probability  \
# 0           0.0                   False           0.999996           0.000004
# 1           NaN                   False           0.999936           0.000063
# 2           NaN                   False           0.943346           0.056607
# 3           NaN                   False           0.995128           0.004871
# 4           NaN                   False           0.727987           0.271991
#
#   Attack_Status  Margin Loss        Label
# 0           NaN     0.999992  QEBA / HSJA
# 1           NaN     0.999872  QEBA / HSJA
# 2           NaN     0.886739  QEBA / HSJA
# 3           NaN     0.990257  QEBA / HSJA
# 4           NaN     0.455996  QEBA / HSJA

# %%
df4.tail()
# Out:
#          CurrentIndex  QEBA_Logits_True/False  Top 1 Probability  \
# 1048570           NaN                   False           0.991372
# 1048571           NaN                   False           0.997313
# 1048572           NaN                   False           0.978855
# 1048573           NaN                   False           0.988028
# 1048574           NaN                   False           0.709561
#
#          Top 2 Probability Attack_Status  Margin Loss        Label
# 1048570           0.006935           NaN     0.984438  QEBA / HSJA
# 1048571           0.001415           NaN     0.995898  QEBA / HSJA
# 1048572           0.013895           NaN     0.964959  QEBA / HSJA
# 1048573           0.011668           NaN     0.976360  QEBA / HSJA
# 1048574           0.287287           NaN     0.422274  QEBA / HSJA

# %% [markdown]
# **Combine QEBA / HSJA**

# %%
# Merging the DataFrames row-wise
df3 = pd.concat([df3, df4], axis=0)

# Resetting the index if needed
df3.reset_index(drop=True, inplace=True)

# %%
df3.shape
# Out:
# (7750566, 8)

# %% [markdown]
# **SURFREE Dataset**

# %%
# Specify the path to your file in Google Drive
file_path = 'SURFREE_cifar10.xlsx'

# %%
df4 = pd.read_excel(file_path)

# %%
# Renaming columns
df4.rename(columns={'SortedList_First_Element': 'Top 1 Probability', 'SortedList_Second_Element': 'Top 2 Probability', 'PredictedLabel_first':'Top 1 Label', 'Predicted_Label_second':'Top 2 Label'}, inplace=True)

# %%
df4['Label'] = 'SURFREE'

# %%
df4.head()
# Out:
#    Surfree_Logits_True/False  Top 1 Probability  Top 2 Probability  \
# 0                      False           0.993475       5.805205e-03
# 1                      False           0.937610       6.213383e-02
# 2                      False           0.998287       1.698936e-03
# 3                      False           0.556448       4.345525e-01
# 4                      False           0.999998       7.861221e-07
#
#   Attack_Status  Margin Loss    Label
# 0           NaN     0.987670  SURFREE
# 1           NaN     0.875476  SURFREE
# 2           NaN     0.996588  SURFREE
# 3           NaN     0.121896  SURFREE
# 4           NaN     0.999997  SURFREE

# %%
df4.tail()
# Out:
#         Surfree_Logits_True/False  Top 1 Probability  Top 2 Probability  \
# 194329                      False           0.964052           0.025270
# 194330                      False           0.788743           0.204339
# 194331                      False           0.910887           0.071277
# 194332                      False           0.964186           0.031899
# 194333                      False           0.684325           0.308581
#
#        Attack_Status  Margin Loss    Label
# 194329           NaN     0.938781  SURFREE
# 194330           NaN     0.584404  SURFREE
# 194331           NaN     0.839611  SURFREE
# 194332           NaN     0.932287  SURFREE
# 194333           NaN     0.375744  SURFREE

# %% [markdown]
# **Combine** **Datasets**

# %%
# Merging the DataFrames row-wise
combined_df = pd.concat([dff, df, df1, df2, df3, df4], axis=0)

# Resetting the index if needed
combined_df.reset_index(drop=True, inplace=True)

# %%
combined_df.head()
# Out:
#    Top 1 Probability  Top 2 Probability  Top 1 Label  Top 2 Label  \
# 0           0.999468       4.765340e-04          0.0          4.0
# 1           0.994223       5.296815e-03          9.0          0.0
# 2           0.999783       2.152990e-04          3.0          5.0
# 3           0.999629       3.543440e-04          5.0          3.0
# 4           1.000000       2.530000e-10          1.0          9.0
#
#    Margin Loss    offset   Label  Iteration  Trail Cache Hits  Noise  \
# 0     0.998991  0.000000  Benign        NaN    NaN        NaN    NaN
# 1     0.988926  0.604090  Benign        NaN    NaN        NaN    NaN
# 2     0.999568  0.561415  Benign        NaN    NaN        NaN    NaN
# 3     0.999275  0.683682  Benign        NaN    NaN        NaN    NaN
# 4     1.000000  0.552765  Benign        NaN    NaN        NaN    NaN
#
#   CurrentIndex IndexLabel NES_Logits_True/False Logits_True/False  \
# 0          NaN        NaN                   NaN               NaN
# 1          NaN        NaN                   NaN               NaN
# 2          NaN        NaN                   NaN               NaN
# 3          NaN        NaN                   NaN               NaN
# 4          NaN        NaN                   NaN               NaN
#
#   HSJA_Logits_True/False Attack_Status QEBA_Logits_True/False  \
# 0                    NaN           NaN                    NaN
# 1                    NaN           NaN                    NaN
# 2                    NaN           NaN                    NaN
# 3                    NaN           NaN                    NaN
# 4                    NaN           NaN                    NaN
#
#   Surfree_Logits_True/False
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
combined_df.tail()
# Out:
#          Top 1 Probability  Top 2 Probability  Top 1 Label  Top 2 Label  \
# 9367883           0.964052           0.025270          NaN          NaN
# 9367884           0.788743           0.204339          NaN          NaN
# 9367885           0.910887           0.071277          NaN          NaN
# 9367886           0.964186           0.031899          NaN          NaN
# 9367887           0.684325           0.308581          NaN          NaN
#
#          Margin Loss  offset    Label  Iteration  Trail Cache Hits  Noise  \
# 9367883     0.938781     NaN  SURFREE        NaN    NaN        NaN    NaN
# 9367884     0.584404     NaN  SURFREE        NaN    NaN        NaN    NaN
# 9367885     0.839611     NaN  SURFREE        NaN    NaN        NaN    NaN
# 9367886     0.932287     NaN  SURFREE        NaN    NaN        NaN    NaN
# 9367887     0.375744     NaN  SURFREE        NaN    NaN        NaN    NaN
#
#         CurrentIndex IndexLabel NES_Logits_True/False Logits_True/False  \
# 9367883          NaN        NaN                   NaN               NaN
# 9367884          NaN        NaN                   NaN               NaN
# 9367885          NaN        NaN                   NaN               NaN
# 9367886          NaN        NaN                   NaN               NaN
# 9367887          NaN        NaN                   NaN               NaN
#
#         HSJA_Logits_True/False Attack_Status QEBA_Logits_True/False  \
# 9367883                    NaN           NaN                    NaN
# 9367884                    NaN           NaN                    NaN
# 9367885                    NaN           NaN                    NaN
# 9367886                    NaN           NaN                    NaN
# 9367887                    NaN           NaN                    NaN
#
#         Surfree_Logits_True/False
# 9367883                     False
# 9367884                     False
# 9367885                     False
# 9367886                     False
# 9367887                     False

# %%
combined_df.shape
# Out:
# (9367888, 19)

# %% [markdown]
# **Boundary** **Sequences**

# %%
# For Label Malware
Boundary_data_sequences = []
Boundary_data_labels = []
malware_data = df[df['Label'] == 'Boundary']

# Identify unique cycles in the Iteration column
cycle_start_indices = malware_data[malware_data['Iteration'] == 1].index.tolist()

# Create sequences for each cycle
for i, start_idx in enumerate(cycle_start_indices):
    if i + 1 < len(cycle_start_indices):
        end_idx = cycle_start_indices[i + 1] - 1
    else:
        end_idx = len(malware_data) - 1

    cycle_data = malware_data.loc[start_idx:end_idx]
    cycle_sequence = cycle_data[['Margin Loss']].to_numpy()
    Boundary_data_sequences.append(cycle_sequence)
    Boundary_data_labels.append(1)  # Label for malware

# %%
Boundary_data_sequences = Boundary_data_sequences[:900]

# %%
len(Boundary_data_sequences)
# Out:
# 1049

# %%
Boundary_data_labels = Boundary_data_labels[:900]

# %%
len(Boundary_data_labels)
# Out:
# 1049

# %%
min_length = []
for i in range(len(Boundary_data_sequences)):
  min_length.append(len(Boundary_data_sequences[i]))
print('minimum length of the Boundary sequence is:', min(min_length))
print('maximum length of the Boundary sequence is:', max(min_length))
# Out:
# minimum length of the Boundary sequence is: 428
# maximum length of the Boundary sequence is: 810

# %%
# Check for None values in benign_data_sequences
if any(seq is None for seq in Boundary_data_sequences):
    print("Found None in Boundary_data_sequences")

# %% [markdown]
# **Benign Sequences**

# %%
# For Label Benign
benign_data_sequences = []
benign_data_labels = []
benign_data = combined_df[combined_df['Label'] == 'Benign']

# Define the target ratio
target_ratio = 1 / 1

# Calculate the number of benign sequences needed
required_benign_sequences = int(len(Boundary_data_sequences) * target_ratio)

while len(benign_data_sequences) < required_benign_sequences:
    # Shuffle the benign data before generating a new sequence
    benign_data = benign_data.sample(frac=1).reset_index(drop=True)

    seq_length = np.random.randint(500, 800)  # Random length between 500 and 800
    if len(benign_data) < seq_length:
        seq_length = len(benign_data)
    sequence = benign_data.iloc[:seq_length][['Margin Loss']].to_numpy()
    benign_data_sequences.append(sequence)
    benign_data_labels.append(0)  # Label for benign
    benign_data = benign_data.iloc[seq_length:]  # Remove the used sequence from the data

# %%
len(benign_data_labels)
# Out:
# 1049

# %%
len(benign_data_sequences)
# Out:
# 1049

# %% [markdown]
# **NES** **sequences**

# %%
# Convert CurrentIndex to numeric, coercing errors so blanks become NaN
df1['CurrentIndex'] = pd.to_numeric(df1['CurrentIndex'], errors='coerce')

# Filter the dataframe to only include rows labeled as 'Malware'
malware_df = df1[df1['Label'] == 'NES']

# Find the indices where CurrentIndex is 0
start_indices = malware_df.index[malware_df['CurrentIndex'] == 0].tolist()

# Initialize list to hold the sequences
sequences = []
NES_data_labels = []

# Loop over the start indices to define sequences
for i, start_index in enumerate(start_indices):
    # Determine the end index (one before the next start index or end of dataframe)
    end_index = start_indices[i + 1] if i + 1 < len(start_indices) else len(malware_df)

    # Extract the sequence
    sequence = malware_df.iloc[start_index:end_index]['Margin Loss']
    sequences.append(sequence)

    NES_data_labels.append(2)

# Convert each sequence DataFrame into a list of lists (rows as lists)
NES_data_sequences = [sequence.values.tolist() for sequence in sequences]

# %%
len(NES_data_labels)
# Out:
# 841

# %%
len(NES_data_sequences)
# Out:
# 841

# %%
min_length = []
for i in range(len(NES_data_sequences)):
  min_length.append(len(NES_data_sequences[i]))
print('minimum length of the NES sequence is:', min(min_length))
print('maximum length of the NES sequence is:', max(min_length))
# Out:
# minimum length of the NES sequence is: 452
# maximum length of the NES sequence is: 3971

# %%
# Check for None values in benign_data_sequences
if any(seq is None for seq in NES_data_sequences):
    print("Found None in NES_data_sequences")

# %% [markdown]
# **Square** **Sequences**

# %%
# Convert CurrentIndex to numeric, coercing errors so blanks become NaN
df2['CurrentIndex'] = pd.to_numeric(df2['CurrentIndex'], errors='coerce')

# Filter the dataframe to only include rows labeled as 'Malware'
malware_df = df2[df2['Label'] == 'Square']

# Find the indices where CurrentIndex is 0
start_indices = malware_df.index[malware_df['CurrentIndex'] == 0].tolist()

# Initialize list to hold the sequences
sequences = []
Square_data_labels = []

# Loop over the start indices to define sequences
for i, start_index in enumerate(start_indices):
    # Determine the end index (one before the next start index or end of dataframe)
    end_index = start_indices[i + 1] if i + 1 < len(start_indices) else len(malware_df)

    # Extract the sequence
    sequence = malware_df.iloc[start_index:end_index]['Margin Loss']
    sequences.append(sequence)

    Square_data_labels.append(3)

# Convert each sequence DataFrame into a list of lists (rows as lists)
Square_data_sequences = [sequence.values.tolist() for sequence in sequences]

# %%
len(Square_data_sequences)
# Out:
# 901

# %%
len(Square_data_labels)
# Out:
# 901

# %%
min_length = []
for i in range(len(Square_data_sequences)):
  min_length.append(len(Square_data_sequences[i]))
print('minimum length of the Square sequence is:', min(min_length))
print('maximum length of the Square sequence is:', max(min_length))
# Out:
# minimum length of the Square sequence is: 152
# maximum length of the Square sequence is: 727

# %%
# Check for None values in benign_data_sequences
if any(seq is None for seq in Square_data_sequences):
    print("Found None in Square_data_sequences")

# %% [markdown]
# **QEBA / HSJA sequences**

# %%
df3.head()
# Out:
#   CurrentIndex HSJA_Logits_True/False  Top 1 Probability  Top 2 Probability  \
# 0            0                  False           0.376380           0.253102
# 1          NaN                  False           0.744554           0.160647
# 2          NaN                  False           0.970433           0.023774
# 3          NaN                  False           0.751087           0.220022
# 4          NaN                  False           0.648171           0.303700
#
#   Attack_Status  Margin Loss        Label QEBA_Logits_True/False
# 0           NaN     0.123278  QEBA / HSJA                    NaN
# 1           NaN     0.583907  QEBA / HSJA                    NaN
# 2           NaN     0.946659  QEBA / HSJA                    NaN
# 3           NaN     0.531065  QEBA / HSJA                    NaN
# 4           NaN     0.344471  QEBA / HSJA                    NaN

# %%
# Find the indices where Attack_Status is 'ATTACK'
attack_indices = df3.index[df3['Attack_Status'] == 'ATTACK'].tolist()

# Initialize list to hold the sequences
hsja_data_sequences = []
hsja_data_labels = []

# Loop over the attack indices to define sequences
for i, attack_index in enumerate(attack_indices):
    # Determine the start index (either 0 or one after the previous attack index)
    start_index = attack_indices[i-1] + 1 if i > 0 else 0

    # Extract the sequence from start to the current attack index
    sequence = df3.iloc[start_index:attack_index]['Margin Loss']
    hsja_data_sequences.append(sequence.values.tolist())

    # Label the sequence
    hsja_data_labels.append(4)

# %%
len(hsja_data_labels)
# Out:
# 1824

# %%
len(hsja_data_sequences)
# Out:
# 1824

# %%
len(hsja_data_sequences[0])
# Out:
# 11628

# %%
min_length = []
for i in range(len(hsja_data_sequences)):
  min_length.append(len(hsja_data_sequences[i]))
print('minimum length of the hsja sequence is:', min(min_length))
print('maximum length of the hsja sequence is:', max(min_length))
# Out:
# minimum length of the hsja sequence is: 328
# maximum length of the hsja sequence is: 300683

# %% [markdown]
# **SURFREE Sequences**

# %%
# Find the indices where Attack_Status is 'ATTACK'
attack_indices = df4.index[df4['Attack_Status'] == 'ATTACK'].tolist()

# Initialize list to hold the sequences
surfree_data_sequences = []
surfree_data_labels = []

# Loop over the attack indices to define sequences
for i, attack_index in enumerate(attack_indices):
    # Determine the start index (either 0 or one after the previous attack index)
    start_index = attack_indices[i-1] + 1 if i > 0 else 0

    # Extract the sequence from start to the current attack index
    sequence = df4.iloc[start_index:attack_index]['Margin Loss']
    surfree_data_sequences.append(sequence.values.tolist())

    # Label the sequence
    surfree_data_labels.append(5)

# %%
len(surfree_data_sequences)
# Out:
# 997

# %%
len(surfree_data_labels)
# Out:
# 997

# %%
len(surfree_data_sequences[0])
# Out:
# 128

# %%
min_length = []
for i in range(len(surfree_data_sequences)):
  min_length.append(len(surfree_data_sequences[i]))
print('minimum length of the surfree sequence is:', min(min_length))
print('maximum length of the surfree sequence is:', max(min_length))
# Out:
# minimum length of the surfree sequence is: 112
# maximum length of the surfree sequence is: 1948

# %% [markdown]
# **Combine** **Sequences** **and** **Labels**

# %%
malware_data_sequences = benign_data_sequences + surfree_data_sequences + hsja_data_sequences + Boundary_data_sequences + NES_data_sequences + Square_data_sequences

# %%
malware_data_labels = benign_data_labels + surfree_data_labels + hsja_data_labels + Boundary_data_labels + NES_data_labels + Square_data_labels

# %%
len(malware_data_sequences)
# Out:
# 6661

# %%
len(malware_data_labels)
# Out:
# 6661

# %%
np.unique(malware_data_labels)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# **Loop with Sequence List**

# %%
sequence_list = [25,30,36,43,52,62,75,90,108,112]

# %%
sequence_list
# Out:
# [25, 30, 36, 43, 52, 62, 75, 90, 108, 112]

# %%
value = [112]

# %%
train_loss_list = []
val_loss_list = []

train_acc_list = []
val_acc_list = []

test_loss_list = []
test_acc_list = []

time_list = []
scores = []

overall_acc_list = []
balanced_acc_list = []

# %%
attack_type = 'Benign_Boundary_NES_Square_HSJA/QEBA_Surfree'

# %%
for i in value:

  def truncate_sequence(sequence, desired_length = i):
      if len(sequence) >= desired_length:
          # Return the first 'desired_length' elements
          return sequence[-desired_length:]
      else:
          # If the sequence is shorter, pad with zeros (or any desired padding value)
          padding = np.zeros((desired_length - len(sequence), sequence.shape[1]))
          return np.vstack((sequence, padding))

  # Apply truncation or padding to all malware and benign sequences
  all_data_sequences_i = [truncate_sequence(seq) for seq in malware_data_sequences]

  # Combine all sequences and labels
  all_data_labels = malware_data_labels

  # Convert each sequence to a NumPy array and then flatten it
  flat_data_sequences = [np.array(seq).flatten() for seq in all_data_sequences_i]

  # Pad the sequences so they all have the same length
  max_length = max(len(seq) for seq in flat_data_sequences)

  # If max_length is not even, increase it by 1 to make it even
  if max_length % 2 != 0:
      max_length += 1

  padded_data_sequences = pad_sequences(flat_data_sequences, maxlen = max_length, dtype='float32', padding='post')

  # Apply standard scaling
  scaler = StandardScaler()
  scaled_data_sequences = scaler.fit_transform(padded_data_sequences)

  # Ensure reshaping will not cause issues
  num_samples = len(scaled_data_sequences)
  num_timesteps = max_length // 2
  num_features = 2

  # Reshape back to 3D if needed (num_samples, num_timesteps, num_features)
  scaled_data_sequences = scaled_data_sequences.reshape((len(scaled_data_sequences), max_length // 2, 2))

  # Perform train-test split
  X_train, X_test, y_train, y_test = train_test_split(scaled_data_sequences, all_data_labels, test_size=0.2, random_state=42)

  # Convert labels to categorical (for multi-class classification)
  num_classes = 6
  y_train_categorical = to_categorical(y_train, num_classes=num_classes)
  y_test_categorical = to_categorical(y_test, num_classes=num_classes)

  model = tf.keras.Sequential([
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(num_classes, activation='softmax')
  ])

  # Compile the model
  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  # Define the EarlyStopping callback
  early_stopping = EarlyStopping(
      monitor='val_accuracy',  # You can also use 'accuracy' for training accuracy
      patience=100,              # Number of epochs with no improvement after which training will be stopped
      verbose=1,               # Prints a message when training stops
      restore_best_weights=True  # Restores the model weights from the epoch with the best value of the monitored quantity
  )

  # Train the model with EarlyStopping
  history = model.fit(
      X_train,
      y_train_categorical,
      validation_split=0.2,
      epochs=100,              # Set a large number of epochs, it will stop early if conditions are met
      batch_size=32,
      callbacks=[early_stopping]  # Include the EarlyStopping callback
  )


  # Assuming 'history' is the result of model.fit()

  # Extract loss and accuracy from the history object
  train_loss = history.history['loss']
  train_loss_list.append(train_loss)

  val_loss = history.history['val_loss']
  val_loss_list.append(val_loss)

  train_acc = history.history['accuracy']
  train_acc_list.append(train_acc)

  val_acc = history.history['val_accuracy']
  val_acc_list.append(val_acc)


  # Create subplots for loss and accuracy
  fig, ax = plt.subplots(1, 2, figsize=(14, 6))

  # Plot training and validation loss
  ax[0].plot(train_loss, label='Train Loss')
  ax[0].plot(val_loss, label='Validation Loss')
  ax[0].set_title('Loss', fontsize=16)
  ax[0].set_xlabel('Epoch', fontsize=16)
  ax[0].set_ylabel('Loss', fontsize=16)
  plt.xticks(fontsize=16)  # Increase font size of x-ticks
  plt.yticks(fontsize=16)
  ax[0].legend(fontsize=16)

  # Plot training and validation accuracy
  ax[1].plot(train_acc, label='Train Accuracy')
  ax[1].plot(val_acc, label='Validation Accuracy')
  ax[1].set_title('Accuracy', fontsize=16)
  ax[1].set_xlabel('Epoch', fontsize=16)
  ax[1].set_ylabel('Accuracy', fontsize=16)
  plt.xticks(fontsize=16)  # Increase font size of x-ticks
  plt.yticks(fontsize=16)
  ax[1].legend(fontsize=16)

  # Add a super title
  plt.suptitle('Training and Validation Metrics - CIFAR-10', fontsize=16)

  plt.tight_layout(rect=[0, 0, 1, 0.95])

  # Save the figure as a PDF
  pdf_filename = 'training_validation_metrics.pdf'
  with PdfPages(pdf_filename) as pdf:
      pdf.savefig(fig)

  plt.show()

  print(f"Plots saved to {pdf_filename}")

  # Evaluate the model on the test set
  test_loss, test_accuracy = model.evaluate(X_test, y_test_categorical)

  test_loss_list.append(test_loss)
  test_acc_list.append(test_accuracy)


  # Predictions
  y_train_pred = np.argmax(model.predict(X_train), axis=1)

  # Start the timer
  start_time = time.time()

  y_test_pred = np.argmax(model.predict(X_test), axis=1)

  # End the timer
  end_time = time.time()

  # Calculate the elapsed time
  elapsed_time = end_time - start_time

  time_list.append(elapsed_time)

  # Calculate training and test errors
  train_error = 1 - accuracy_score(y_train, y_train_pred)
  test_error = 1 - accuracy_score(y_test, y_test_pred)


  # Overall accuracy
  overall_accuracy = accuracy_score(y_test, y_test_pred)
  overall_acc_list.append(overall_accuracy)

  # Balanced accuracy
  balanced_accuracy = balanced_accuracy_score(y_test, y_test_pred)
  balanced_acc_list.append(balanced_accuracy)



  # Define the class labels manually
  class_labels = ['Benign', 'Surfree', 'QEBA / HSJA', 'Boundary', 'NES', 'Square']


  ### confusion matrix -- Test data


  # Compute and plot confusion matrix
  conf_matrix = confusion_matrix(y_test, y_test_pred)
  disp = ConfusionMatrixDisplay(conf_matrix, display_labels=['Benign','Surfree', 'QEBA / HSJA', 'Boundary', 'NES', 'Square'])
  disp.plot(cmap='Blues', xticks_rotation=45)
  plt.suptitle('Confusion Matrix - Cifar-10', fontsize=16)
  plt.savefig("confusion_matrix_multiclass_cifar_10.png", bbox_inches='tight', dpi=1000)
  plt.show()



  ### classification report
  # Define a directory where you want to save the reports
  output_dir = './output_reports'  # Create a folder for saving reports if it doesn't exist

  # Ensure the directory exists
  os.makedirs(output_dir, exist_ok=True)

  # Generate classification report
  report = classification_report(y_test, y_test_pred, target_names=class_labels)

  # Construct the file path
  report_filename = f'{output_dir}/Classification_Report_last_{i}.txt'

  # Save the classification report to a text file
  with open(report_filename, 'w') as file:
      file.write(f"Classification Report:\n{report}")

  # Download the file to your local machine
  files.download(report_filename)

  # Generate the classification report as a dictionary
  report_dict = classification_report(y_test, y_test_pred, target_names=class_labels, output_dict=True)

  # Extract the macro-average F1 score
  macro_avg_f1_score = report_dict['macro avg']['f1-score']

  scores.append(macro_avg_f1_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 147s 996ms/step - accuracy: 0.6065 - loss: 0.9628 - val_accuracy: 0.7730 - val_loss: 0.5437
# Epoch 2/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8309 - loss: 0.4337 - val_accuracy: 0.8049 - val_loss: 0.4443
# Epoch 3/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.8772 - loss: 0.3317 - val_accuracy: 0.9137 - val_loss: 0.2498
# Epoch 4/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9145 - loss: 0.2419 - val_accuracy: 0.9231 - val_loss: 0.2296
# Epoch 5/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9260 - loss: 0.2076 - val_accuracy: 0.9296 - val_loss: 0.2002
# Epoch 6/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 137s 975ms/step - accuracy: 0.9354 - loss: 0.1877 - val_accuracy: 0.9325 - val_loss: 0.1866
# Epoch 7/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.9279 - loss: 0.2039 - val_accuracy: 0.9118 - val_loss: 0.2242
# Epoch 8/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 982ms/step - accuracy: 0.9429 - loss: 0.1600 - val_accuracy: 0.9006 - val_loss: 0.2408
# Epoch 9/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 977ms/step - accuracy: 0.9495 - loss: 0.1414 - val_accuracy: 0.9315 - val_loss: 0.1775
# Epoch 10/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 978ms/step - accuracy: 0.9531 - loss: 0.1300 - val_accuracy: 0.9447 - val_loss: 0.1670
# Epoch 11/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 129s 966ms/step - accuracy: 0.9515 - loss: 0.1372 - val_accuracy: 0.9437 - val_loss: 0.1879
# Epoch 12/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 982ms/step - accuracy: 0.9611 - loss: 0.1124 - val_accuracy: 0.9447 - val_loss: 0.1704
# Epoch 13/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 965ms/step - accuracy: 0.9650 - loss: 0.0973 - val_accuracy: 0.9550 - val_loss: 0.1298
# Epoch 14/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 944ms/step - accuracy: 0.9661 - loss: 0.0976 - val_accuracy: 0.9522 - val_loss: 0.1481
# Epoch 15/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 148s 986ms/step - accuracy: 0.9719 - loss: 0.0742 - val_accuracy: 0.9418 - val_loss: 0.1740
# Epoch 16/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 966ms/step - accuracy: 0.9637 - loss: 0.0975 - val_accuracy: 0.9653 - val_loss: 0.1066
# Epoch 17/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 970ms/step - accuracy: 0.9731 - loss: 0.0738 - val_accuracy: 0.9578 - val_loss: 0.1108
# Epoch 18/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9748 - loss: 0.0723 - val_accuracy: 0.9418 - val_loss: 0.1543
# Epoch 19/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.9724 - loss: 0.0809 - val_accuracy: 0.9700 - val_loss: 0.0970
# Epoch 20/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 185s 976ms/step - accuracy: 0.9719 - loss: 0.0756 - val_accuracy: 0.9634 - val_loss: 0.1169
# Epoch 21/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 138s 947ms/step - accuracy: 0.9768 - loss: 0.0693 - val_accuracy: 0.9644 - val_loss: 0.1176
# Epoch 22/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 944ms/step - accuracy: 0.9839 - loss: 0.0493 - val_accuracy: 0.9700 - val_loss: 0.0929
# Epoch 23/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 944ms/step - accuracy: 0.9826 - loss: 0.0505 - val_accuracy: 0.9653 - val_loss: 0.0943
# Epoch 24/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 946ms/step - accuracy: 0.9848 - loss: 0.0453 - val_accuracy: 0.9578 - val_loss: 0.1565
# Epoch 25/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 943ms/step - accuracy: 0.9761 - loss: 0.0638 - val_accuracy: 0.9672 - val_loss: 0.1160
# Epoch 26/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 939ms/step - accuracy: 0.9804 - loss: 0.0504 - val_accuracy: 0.9719 - val_loss: 0.0765
# Epoch 27/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 940ms/step - accuracy: 0.9821 - loss: 0.0492 - val_accuracy: 0.9747 - val_loss: 0.0766
# Epoch 28/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 946ms/step - accuracy: 0.9881 - loss: 0.0347 - val_accuracy: 0.9597 - val_loss: 0.1221
# Epoch 29/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 942ms/step - accuracy: 0.9767 - loss: 0.0579 - val_accuracy: 0.9700 - val_loss: 0.0918
# Epoch 30/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 953ms/step - accuracy: 0.9850 - loss: 0.0397 - val_accuracy: 0.9794 - val_loss: 0.0651
# Epoch 31/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 939ms/step - accuracy: 0.9800 - loss: 0.0594 - val_accuracy: 0.9597 - val_loss: 0.1237
# Epoch 32/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 938ms/step - accuracy: 0.9861 - loss: 0.0386 - val_accuracy: 0.9747 - val_loss: 0.0762
# Epoch 33/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 127s 952ms/step - accuracy: 0.9857 - loss: 0.0425 - val_accuracy: 0.9700 - val_loss: 0.0924
# Epoch 34/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 944ms/step - accuracy: 0.9860 - loss: 0.0315 - val_accuracy: 0.9747 - val_loss: 0.0863
# Epoch 35/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 132s 984ms/step - accuracy: 0.9869 - loss: 0.0335 - val_accuracy: 0.9728 - val_loss: 0.0803
# Epoch 36/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 989ms/step - accuracy: 0.9834 - loss: 0.0428 - val_accuracy: 0.9719 - val_loss: 0.0934
# Epoch 37/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.9897 - loss: 0.0310 - val_accuracy: 0.9728 - val_loss: 0.0769
# Epoch 38/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 135s 995ms/step - accuracy: 0.9826 - loss: 0.0461 - val_accuracy: 0.9747 - val_loss: 0.0751
# Epoch 39/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 132s 987ms/step - accuracy: 0.9903 - loss: 0.0256 - val_accuracy: 0.9794 - val_loss: 0.0734
# Epoch 40/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 973ms/step - accuracy: 0.9946 - loss: 0.0154 - val_accuracy: 0.9690 - val_loss: 0.1023
# Epoch 41/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 129s 961ms/step - accuracy: 0.9893 - loss: 0.0286 - val_accuracy: 0.9775 - val_loss: 0.1074
# Epoch 42/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 129s 965ms/step - accuracy: 0.9878 - loss: 0.0337 - val_accuracy: 0.9756 - val_loss: 0.0585
# Epoch 43/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 978ms/step - accuracy: 0.9905 - loss: 0.0233 - val_accuracy: 0.9681 - val_loss: 0.0907
# Epoch 44/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 131s 977ms/step - accuracy: 0.9863 - loss: 0.0323 - val_accuracy: 0.9831 - val_loss: 0.0650
# Epoch 45/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 982ms/step - accuracy: 0.9910 - loss: 0.0203 - val_accuracy: 0.9662 - val_loss: 0.1181
# Epoch 46/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 968ms/step - accuracy: 0.9876 - loss: 0.0307 - val_accuracy: 0.9756 - val_loss: 0.0791
# Epoch 47/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 977ms/step - accuracy: 0.9856 - loss: 0.0345 - val_accuracy: 0.9728 - val_loss: 0.0969
# Epoch 48/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 976ms/step - accuracy: 0.9862 - loss: 0.0362 - val_accuracy: 0.9568 - val_loss: 0.1493
# Epoch 49/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 137s 938ms/step - accuracy: 0.9771 - loss: 0.0537 - val_accuracy: 0.9775 - val_loss: 0.0734
# Epoch 50/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 122s 915ms/step - accuracy: 0.9880 - loss: 0.0383 - val_accuracy: 0.9719 - val_loss: 0.0743
# Epoch 51/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 933ms/step - accuracy: 0.9943 - loss: 0.0179 - val_accuracy: 0.9803 - val_loss: 0.0641
# Epoch 52/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 944ms/step - accuracy: 0.9943 - loss: 0.0182 - val_accuracy: 0.9831 - val_loss: 0.0655
# Epoch 53/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 961ms/step - accuracy: 0.9906 - loss: 0.0273 - val_accuracy: 0.9737 - val_loss: 0.0876
# Epoch 54/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 128s 958ms/step - accuracy: 0.9860 - loss: 0.0428 - val_accuracy: 0.9719 - val_loss: 0.0970
# Epoch 55/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 972ms/step - accuracy: 0.9947 - loss: 0.0162 - val_accuracy: 0.9822 - val_loss: 0.0566
# Epoch 56/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 948ms/step - accuracy: 0.9874 - loss: 0.0330 - val_accuracy: 0.9719 - val_loss: 0.0990
# Epoch 57/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 940ms/step - accuracy: 0.9899 - loss: 0.0269 - val_accuracy: 0.9765 - val_loss: 0.0803
# Epoch 58/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 943ms/step - accuracy: 0.9891 - loss: 0.0272 - val_accuracy: 0.9709 - val_loss: 0.0758
# Epoch 59/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 940ms/step - accuracy: 0.9903 - loss: 0.0223 - val_accuracy: 0.9719 - val_loss: 0.1007
# Epoch 60/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 126s 938ms/step - accuracy: 0.9959 - loss: 0.0124 - val_accuracy: 0.9615 - val_loss: 0.1015
# Epoch 61/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 944ms/step - accuracy: 0.9881 - loss: 0.0393 - val_accuracy: 0.9747 - val_loss: 0.0645
# Epoch 62/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 940ms/step - accuracy: 0.9913 - loss: 0.0254 - val_accuracy: 0.9841 - val_loss: 0.0532
# Epoch 63/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 945ms/step - accuracy: 0.9877 - loss: 0.0300 - val_accuracy: 0.9775 - val_loss: 0.0938
# Epoch 64/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 941ms/step - accuracy: 0.9896 - loss: 0.0256 - val_accuracy: 0.9728 - val_loss: 0.0853
# Epoch 65/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 127s 947ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 0.9747 - val_loss: 0.1118
# Epoch 66/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 930ms/step - accuracy: 0.9901 - loss: 0.0267 - val_accuracy: 0.9765 - val_loss: 0.0858
# Epoch 67/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 124s 930ms/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9784 - val_loss: 0.0642
# Epoch 68/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 941ms/step - accuracy: 0.9916 - loss: 0.0231 - val_accuracy: 0.9737 - val_loss: 0.0995
# Epoch 69/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 938ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.9737 - val_loss: 0.0987
# Epoch 70/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 951ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9784 - val_loss: 0.0707
# Epoch 71/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 953ms/step - accuracy: 0.9918 - loss: 0.0273 - val_accuracy: 0.9775 - val_loss: 0.0652
# Epoch 72/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 945ms/step - accuracy: 0.9954 - loss: 0.0113 - val_accuracy: 0.9794 - val_loss: 0.0754
# Epoch 73/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 950ms/step - accuracy: 0.9977 - loss: 0.0083 - val_accuracy: 0.9859 - val_loss: 0.0547
# Epoch 74/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 127s 946ms/step - accuracy: 0.9946 - loss: 0.0109 - val_accuracy: 0.9831 - val_loss: 0.0593
# Epoch 75/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 950ms/step - accuracy: 0.9957 - loss: 0.0086 - val_accuracy: 0.9841 - val_loss: 0.0677
# Epoch 76/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 947ms/step - accuracy: 0.9961 - loss: 0.0070 - val_accuracy: 0.9737 - val_loss: 0.1002
# Epoch 77/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 130s 973ms/step - accuracy: 0.9956 - loss: 0.0166 - val_accuracy: 0.9794 - val_loss: 0.0863
# Epoch 78/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 976ms/step - accuracy: 0.9953 - loss: 0.0147 - val_accuracy: 0.9765 - val_loss: 0.0944
# Epoch 79/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 140s 964ms/step - accuracy: 0.9956 - loss: 0.0153 - val_accuracy: 0.9756 - val_loss: 0.0930
# Epoch 80/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 138s 935ms/step - accuracy: 0.9904 - loss: 0.0201 - val_accuracy: 0.9765 - val_loss: 0.0941
# Epoch 81/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 143s 939ms/step - accuracy: 0.9943 - loss: 0.0142 - val_accuracy: 0.9737 - val_loss: 0.0874
# Epoch 82/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 145s 962ms/step - accuracy: 0.9929 - loss: 0.0179 - val_accuracy: 0.9831 - val_loss: 0.0675
# Epoch 83/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 137s 927ms/step - accuracy: 0.9972 - loss: 0.0082 - val_accuracy: 0.9831 - val_loss: 0.0759
# Epoch 84/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 945ms/step - accuracy: 0.9977 - loss: 0.0089 - val_accuracy: 0.9822 - val_loss: 0.0818
# Epoch 85/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 943ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9653 - val_loss: 0.1014
# Epoch 86/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 147s 978ms/step - accuracy: 0.9861 - loss: 0.0417 - val_accuracy: 0.9756 - val_loss: 0.0992
# Epoch 87/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9854 - loss: 0.0375 - val_accuracy: 0.9803 - val_loss: 0.0792
# Epoch 88/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9948 - loss: 0.0143 - val_accuracy: 0.9784 - val_loss: 0.0792
# Epoch 89/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.9944 - loss: 0.0167 - val_accuracy: 0.9822 - val_loss: 0.0618
# Epoch 90/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 192s 992ms/step - accuracy: 0.9941 - loss: 0.0145 - val_accuracy: 0.9784 - val_loss: 0.0628
# Epoch 91/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 968ms/step - accuracy: 0.9965 - loss: 0.0071 - val_accuracy: 0.9794 - val_loss: 0.0626
# Epoch 92/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 986ms/step - accuracy: 0.9977 - loss: 0.0056 - val_accuracy: 0.9756 - val_loss: 0.0730
# Epoch 93/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 0.9775 - val_loss: 0.0730
# Epoch 94/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 0.9747 - val_loss: 0.1216
# Epoch 95/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9903 - loss: 0.0352 - val_accuracy: 0.9784 - val_loss: 0.0705
# Epoch 96/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 137s 973ms/step - accuracy: 0.9909 - loss: 0.0219 - val_accuracy: 0.9756 - val_loss: 0.0988
# Epoch 97/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 144s 988ms/step - accuracy: 0.9949 - loss: 0.0144 - val_accuracy: 0.9737 - val_loss: 0.0927
# Epoch 98/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 141s 982ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.9756 - val_loss: 0.0811
# Epoch 99/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.9921 - loss: 0.0202 - val_accuracy: 0.9756 - val_loss: 0.0713
# Epoch 100/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 138s 990ms/step - accuracy: 0.9931 - loss: 0.0177 - val_accuracy: 0.9784 - val_loss: 0.0727
# Restoring model weights from the end of the best epoch: 73.
# Plots saved to training_validation_metrics.pdf
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 304ms/step - accuracy: 0.9883 - loss: 0.0635
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 47s 276ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 294ms/step
